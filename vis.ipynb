# %%
# %load_ext vimception
import numpy as np
import pandas as pd
# Out:
# The vimception extension is already loaded. To reload it, use:
#   %reload_ext vimception

# %%
'''
munges the pois of Copenhagen such a museums and churches and parks and so on
'''

import folium
import json
import pandas as pd
import geohash
import time
from shapely.geometry import shape, Point, Polygon
from shapely.prepared import prep # speed up


df = pd.DataFrame.from_csv('data/stednavn_flade.csv')
# Polygon(

def poligonify(row):
    a = row.wkb_geometry
    try:
        c =  np.array( [float(i.rstrip(',')) for i in a[10:].translate(None, '()').split(' ')])
        c = c.reshape(c.shape[0]/2, c.shape[0]/(c.shape[0]/2))
        Polygon(c)
    except:
        print 'error'
    return Polygon(c)

# %%
df['poly']  = df.apply(poligonify, axis=1)

# %%
df['centroids'] = df.apply(lambda row: Point(row.poly.centroid), axis=1)

# %% [markdown]
# Guen traffic data

# %%
pd.io.json.read_json('data/trafiktal.json')
# Out:
#                              coords  count
# 0    [12.5652518224, 55.6779317712]  48900
# 1    [12.5876001064, 55.6811636024]  13000
# 2    [12.5871618742, 55.6757645961]  15900
# 3     [12.5635751291, 55.686847826]      0
# 4    [12.5579175401, 55.6779768138]   5500
# 5    [12.5110316027, 55.6506198519]  35900
# 6    [12.5998456363, 55.6384850906]  12500
# 7    [12.5725037339, 55.6759724596]   1600
# 8    [12.5726835281, 55.6832113423]      0
# 9     [12.565982915, 55.6858479448]   4900
# 10   [12.5253921293, 55.7265612736]  15200
# 11   [12.4671310182, 55.7133618163]  19300
# 12   [12.5010678069, 55.6424147972]  14200
# 13   [12.5665450505, 55.6864122861]   4300
# 14   [12.4873895435, 55.6777716243]  18700
# 15    [12.559080063, 55.6817756591]  51600
# 16   [12.4957466796, 55.7196225295]  49500
# 17    [12.524266153, 55.6967735712]  15700
# 18   [12.5477605894, 55.6934037896]  16100
# 19   [12.4682806633, 55.6914907608]  29000
# 20   [12.5699698006, 55.6671083909]  35100
# 21   [12.5869988781, 55.6748929407]  24000
# 22   [12.5822956552, 55.6799856777]   5700
# 23    [12.5785247134, 55.670428838]      0
# 24    [12.5785247134, 55.670428838]      0
# 25   [12.5568218166, 55.7186433952]  63300
# 26   [12.5623101508, 55.7020956736]  30800
# 27    [12.570985145, 55.6820371839]   2800
# 28   [12.5667381925, 55.6792163042]   9900
# 29    [12.476224094, 55.6727246862]  38500
# ..                              ...    ...
# 577  [12.5629338055, 55.6679784982]    900
# 578   [12.5863811085, 55.683830447]   6600
# 579  [12.5613795192, 55.7135942429]   1100
# 580  [12.6122182673, 55.6617934889]   4800
# 581  [12.5132134958, 55.6554599268]   4300
# 582  [12.5802562001, 55.6972676521]    800
# 583  [12.5884186834, 55.6986623592]    700
# 584  [12.5794405889, 55.6982569756]   1200
# 585  [12.5782464302, 55.7015927192]    500
# 586  [12.5783261835, 55.7020931499]    200
# 587  [12.5783494977, 55.7025824737]    600
# 588    [12.5853236939, 55.66597919]   1400
# 589   [12.5810436771, 55.702290724]    600
# 590  [12.5809145105, 55.6989429655]    900
# 591  [12.5398482008, 55.6650844698]    800
# 592  [12.5734435347, 55.6346443739]   9700
# 593  [12.5921131139, 55.7034401727]      0
# 594  [12.5629179813, 55.6733762695]   7700
# 595  [12.5880141366, 55.7030534582]      0
# 596  [12.6062133307, 55.6830547448]   2700
# 597  [12.5472124566, 55.6678564808]    600
# 598   [12.5215365759, 55.695889102]    800
# 599  [12.5405183225, 55.6972110394]   7400
# 600  [12.6069420639, 55.6423490529]   3700
# 601   [12.587548667, 55.6637080197]   7500
# 602  [12.5419555204, 55.6661703581]   4100
# 603  [12.5610724978, 55.6928275902]   3700
# 604  [12.5967948572, 55.6739060582]   3200
# 605  [12.5204751113, 55.7111479897]   2000
# 606  [12.5774360182, 55.6927348085]   6400
#
# [607 rows x 2 columns]

# %%
# load GeoJSON file containing sectors
with open('data/taxzone.json', 'r') as f:
    js = json.load(f)

# %%
polygons_shape = [shape(feature['geometry']) for feature in  js['features']]
names = [feature['properties']['id'] for feature in js['features']]
map_df =  pd.DataFrame({'poly':polygons_shape,'id':names})

# %%
def do(row):
    return len(filter(row.poly.contains, df.centroids))

# %%
map_df['counts'] = map_df.apply(do,axis=1)

# %%
map_df.head()
# Out:
#    id                                               poly  counts
# 0   7  POLYGON ((12.57973653249631 55.67897122530934,...       1
# 1   8  POLYGON ((12.57538207559375 55.67573395017224,...      10
# 2   9  POLYGON ((12.5826025317837 55.67674174792494, ...       2
# 3  10  POLYGON ((12.58490556052964 55.68094553600795,...       2
# 4  11  POLYGON ((12.58545941355171 55.67970058349196,...       1

# %%
cph_location = [56.3,11]
outfile = 'cph.html'
geo_path = 'data/taxzone.json'
map = folium.Map(location=cph_location, zoom_start=7, tiles='Stamen Toner',width=700, height = 700)
map.geo_json(geo_path=geo_path, data_out ='test.json', data=map_df,
             columns=['id', 'counts'],
             key_on='feature.properties.id',
             fill_color='YlGnBu', fill_opacity=0.8, line_opacity=0.3,
             legend_name='Total Number of users in January  2014')
map.create_map(path=outfile)

# %%
# !git pull
# Out:
# Already up-to-date.

# %%
# !git add vis.ipynb
# !git commit -am 'added data '
# !git push origin master
# Out:
# [master 6904691] added data
#  2 files changed, 664 insertions(+), 1261 deletions(-)
#  rewrite geovis.ipynb (83%)
#  create mode 100644 vis.ipynb
# Counting objects: 3, done.
# Delta compression using up to 8 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 662 bytes | 0 bytes/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# To git@github.com:giulioungaretti/opendatahacklab2014.git
#    b3d5856..6904691  master -> master
