# %%
# %load_ext vimception
import numpy as np
import pandas as pd
# Out:
# The vimception extension is already loaded. To reload it, use:
#   %reload_ext vimception

# %%
'''
munges the pois of Copenhagen such a museums and churches and parks and so on
'''

import folium
import json
import pandas as pd
import geohash
import time
from shapely.geometry import shape, Point, Polygon
from shapely.prepared import prep # speed up


df = pd.DataFrame.from_csv('data/stednavn_flade.csv')
# Polygon(

def poligonify(row):
    a = row.wkb_geometry
    try:
        c =  np.array( [float(i.rstrip(',')) for i in a[10:].translate(None, '()').split(' ')])
        c = c.reshape(c.shape[0]/2, c.shape[0]/(c.shape[0]/2))
        Polygon(c)
    except:
        print 'error'
    return Polygon(c)

# %%
df['poly']  = df.apply(poligonify, axis=1)

# %%
df['centroids'] = df.apply(lambda row: Point(row.poly.centroid), axis=1)

# %% [markdown]
# Guen traffic data

# %%
trafic = pd.io.json.read_json('data/trafiktal.json')
trafic['points'] = trafic.apply(lambda row: Point(row.coords), axis=1)

# %% [markdown]
# Parkin data henri

# %% [markdown]
# Average age

# %%
age = pd.io.json.read_json('data/average_age.json')
age['points'] = age.apply(lambda row: Point(row.coords), axis=1)

# %%
# load GeoJSON file containing sectors
with open('data/taxzone.json', 'r') as f:
    js = json.load(f)

# %%
polygons_shape = [shape(feature['geometry']) for feature in  js['features']]
names = [feature['properties']['id'] for feature in js['features']]
map_df =  pd.DataFrame({'poly':polygons_shape,'id':names})

# %%
def do(row):
    return len(filter(row.poly.contains, df.centroids))

# %%
def magic(df):
    res = {}
    for polygon in map_df.poly:
        counts =0 
        for point in df.points:
            if polygon.contains(point):
                counts += int(df['count'][df.points==point])
        res[polygon] = counts
    return res

# %%
map_df_age = pd.DataFrame({'poly':res.keys(),'counts':magic(age).values()})

# %%
map_df_trafic = pd.DataFrame({'poly':res.keys(),'counts':magic(trafic).values()})

# %%
map_df['poicounts'] = map_df.apply(do,axis=1)

# %%
data = pd.merge(map_df, map_df_trafic, on='poly', how='outer')
data = pd.merge(data, map_df_age on='poly', how='outer')

# %%
data['index'] = 2* data.poicounts + 0.5 * data.counts

# %%
data
# Out:
#       id                                               poly  poicounts  \
# 0      7  POLYGON ((12.57973653249631 55.67897122530934,...          1
# 1      8  POLYGON ((12.57538207559375 55.67573395017224,...         10
# 2      9  POLYGON ((12.5826025317837 55.67674174792494, ...          2
# 3     10  POLYGON ((12.58490556052964 55.68094553600795,...          2
# 4     11  POLYGON ((12.58545941355171 55.67970058349196,...          1
# 5     12  POLYGON ((12.56625392688763 55.67856006861916,...          2
# 6     13  POLYGON ((12.5684420463914 55.67670315220757, ...          4
# 7     14  POLYGON ((12.57177221890905 55.67510049945103,...          2
# 384  369  POLYGON ((12.61445079791065 55.6667098169454, ...          0
# 385  370  POLYGON ((12.61320632760095 55.66177877713672,...          2
# 386  371  POLYGON ((12.61556210177551 55.66693466031993,...          0
# 387  372  POLYGON ((12.63160112784015 55.66943215608359,...          7
# 388  373  POLYGON ((12.60789309085473 55.65805777699249,...          1
# 389  374  POLYGON ((12.60905289375783 55.656785120835, 1...          0
# 390  375  POLYGON ((12.61061456480175 55.6597141802376, ...          3
# 391  376  POLYGON ((12.61198317083618 55.65764268367553,...          1
# 392  377  POLYGON ((12.61015518859203 55.65510657317945,...          0
# 393  378  POLYGON ((12.61097526552272 55.65370693268945,...          1
# 394  257  POLYGON ((12.48274952886698 55.66276454846194,...          5
# 395  241  POLYGON ((12.4677744058796 55.6915095173667, 1...          2
#
#      counts  index
# 0         0      2
# 1     18500   9270
# 2         0      4
# 3     12900   6454
# 4     24900  12452
# 5      4800   2404
# 6      8100   4058
# 7     39300  19654
# 8         0      4
# 9      7700   3854
# 10     1800    910
# 11     3600   1808
# 12        0      4
# 13     5000   2502
# 14    13200   6600
# 15    13000   6500
# 16    39900  19962
# 17      100     54
# 18    13200   6608
# 19        0      4
# 20        0      0
# 21     6600   3300
# 22        0      4
# 23        0     10
# 24        0      2
# 25        0      2
# 26        0      0
# 27     2100   1052
# 28     8800   4410
# 29     8900   4450
# ..      ...    ...
# 366    4300   2156
# 367    2300   1156
# 368       0      2
# 369    3300   1652
# 370       0      8
# 371   14900   7472
# 372       0      2
# 373   21400  10706
# 374   19700   9854
# 375   25300  12652
# 376       0      0
# 377    1600    806
# 378   11600   5802
# 379       0      6
# 380   13000   6502
# 381       0      2
# 382       0      2
# 383    7600   3800
# 384       0      0
# 385       0      4
# 386       0      0
# 387   14200   7114
# 388       0      2
# 389       0      0
# 390   11500   5756
# 391    1000    502
# 392       0      0
# 393       0      2
# 394   15700   7860
# 395       0      4
#
# [396 rows x 5 columns]

# %%
cph_location = [55.6181, 12.6561]
outfile = 'cph.html'
geo_path = 'data/taxzone.json'
map = folium.Map(location=cph_location, zoom_start=12, tiles='Stamen Toner',width=1300, height =1300)
map.geo_json(geo_path=geo_path, data_out ='test.json', data=data,
             columns=['id', 'index'],
             key_on='feature.properties.id',
             fill_color='YlGnBu', fill_opacity=0.8, line_opacity=0.3,
             legend_name='trafficcounts')
map.create_map(path=outfile)

# %%
# !git pull

# %%
# !git add vis.ipynb
# !git commit -am 'magic function'
# !git push origin master
# Out:
# On branch master
# Your branch is up-to-date with 'origin/master'.
#
# Untracked files:
# 	example.csv
# 	example/data.csv
# 	npm-debug.log
# 	pois.py
# 	test.json
#
# nothing added to commit but untracked files present
# Everything up-to-date
